# %% [markdown]
# **Mount Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Clone Repo**

# %%
# !git clone https://sibiribigbe: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@github.gatech.edu/eroerty3/defi_detectives.git
# Out:
# Cloning into 'defi_detectives'...
# remote: Enumerating objects: 204, done.
# remote: Counting objects: 100% (204/204), done.
# remote: Compressing objects: 100% (136/136), done.
# remote: Total 204 (delta 81), reused 150 (delta 54), pack-reused 0 (from 0)
# Receiving objects: 100% (204/204), 376.97 KiB | 572.00 KiB/s, done.
# Resolving deltas: 100% (81/81), done.

# %% [markdown]
# **Re-pull repo/refresh as needed after updates**

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 26 (delta 11), reused 11 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (26/26), 9.51 KiB | 885.00 KiB/s, done.
# From https://github.gatech.edu/eroerty3/defi_detectives
#  * branch            main       -> FETCH_HEAD
#    216384c..cedca88  main       -> origin/main
# Updating 216384c..cedca88
# Fast-forward
#  configs/graphsage_base.yaml                  |   26 +
#  configs/graphsage_sweep.yaml                 |   13 +
#  reports/generalization_test_results.json     |   63 +
#  reports/graphsage_best_config.yaml           |   22 +
#  reports/graphsage_sweep_results.json         | 3035 ++++++++++++++++++++++++++
#  requirements.txt                             |    1 +
#  src/data/download_elliptic.py                |    2 -
#  src/data/download_ethereum_kaggle.py         |  138 ++
# ...

# %% [markdown]
# **Navigate to repo folder**

# %%
# %cd /content/defi_detectives/
# Out:
# /content/defi_detectives

# %%
# pip install -r requirements.txt

# %% [markdown]
# **Create Kaggle Json**

# %%
# create kaggle json
#  import json
# import os

# kaggle_dir = os.path.expanduser("~/.kaggle")
# os.makedirs(kaggle_dir, exist_ok=True)

# kaggle_creds = {
#     "username": "USERNAME",
#     "key": "TOKEN"
# }

# with open(os.path.join(kaggle_dir, "kaggle.json"), "w") as f:
#     json.dump(kaggle_creds, f)

# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# **Download Elliptic Dataset From Kaggle**

# %%
# !python src/data/download_elliptic.py
# Out:
# ...
# Download complete.
# Files in directory:
#  - elliptic_bitcoin_dataset

# %% [markdown]
# **Pre-process Elliptic Dataset**

# %%
# !python src/data/preprocess_elliptic.py
# Out:
# Saved baseline artifacts to: data/processed/baseline
# Saved graph artifacts to: data/processed/graph
# Saved splits to: data/processed/splits

# %%
# !python src/models/rf_xgb.py

# %% [markdown]
# **Run EDA Python code as a module**

# %%
# %run src/data/eda.py
# Out:
# Starting EDA...
# Training and Test Lengths:
# 0
# Train max timestep: 49
# Test min timestep: 1
# Train timestep range: 1 49
# Test timestep range: 1 49
# Overlap in time: {np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8), np.int64(9), np.int64(10), np.int64(11), np.int64(12), np.int64(13), np.int64(14), np.int64(15), np.int64(16), np.int64(17), np.int64(18), np.int64(19), np.int64(20), np.int64(21), np.int64(22), np.int64(23), np.int64(24), np.int64(25), np.int64(26), np.int64(27), np.int64(28), np.int64(29), np.int64(30), np.int64(31), np.int64(32), np.int64(33), np.int64(34), np.int64(35), np.int64(36), np.int64(37), np.int64(38), np.int64(39), np.int64(40), np.int64(41), np.int64(42), np.int64(43), np.int64(44), np.int64(45), np.int64(46), np.int64(47), np.int64(48), np.int64(49)}
# Shape: (203769, 168)
#
# Missing values: 0
#
# Class distribution:
# label
# -1    157205
#  0     42019
#  1      4545
# ...

# %% [markdown]
# **Run Baseline Model's Python code**

# %%
# %run src/models/rf_xgb
# Out:
# Training Random Forest...
#
# Training XGBoost...
# Evaluating models...
#
# ...
#  Model: Random Forest
#  Threshold: 0.5
# ...
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6303
#            1       0.96      0.91      0.93       682
#
#     accuracy                           0.99      6985
#    macro avg       0.97      0.95      0.96      6985
# weighted avg       0.99      0.99      0.99      6985
#
# ROC-AUC: 0.9941960794166349
# Average Precision (AP): 0.9717570749952692
#
# Fraud-class metrics (label=1):
# Precision: 0.9567901234567902
# Recall: 0.9090909090909091
# F1-score: 0.9323308270676691
#
# ...
#  Model: XGBoost
#  Threshold: 0.5
# ...
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6303
#            1       0.98      0.94      0.96       682
#
#     accuracy                           0.99      6985
# ...

# %%
# %run src/models/link_prediction.py
# Out:
# Epoch 000 | Loss 1.1868 | Val AUC 0.6511 | Val AP 0.6414
# Epoch 001 | Loss 0.7111 | Val AUC 0.6850 | Val AP 0.6600
# Epoch 002 | Loss 0.6839 | Val AUC 0.7039 | Val AP 0.6718
# Epoch 003 | Loss 0.6791 | Val AUC 0.7219 | Val AP 0.6888
# Epoch 004 | Loss 0.6446 | Val AUC 0.7441 | Val AP 0.7125
# Epoch 005 | Loss 0.5950 | Val AUC 0.7639 | Val AP 0.7349
# Epoch 006 | Loss 0.5608 | Val AUC 0.7793 | Val AP 0.7513
# Epoch 007 | Loss 0.5401 | Val AUC 0.7901 | Val AP 0.7625
# Epoch 008 | Loss 0.5297 | Val AUC 0.7980 | Val AP 0.7713
# Epoch 009 | Loss 0.5235 | Val AUC 0.8049 | Val AP 0.7798
# Epoch 010 | Loss 0.5177 | Val AUC 0.8115 | Val AP 0.7883
# Epoch 011 | Loss 0.5101 | Val AUC 0.8169 | Val AP 0.7956
# Epoch 012 | Loss 0.5017 | Val AUC 0.8205 | Val AP 0.8009
# Epoch 013 | Loss 0.4951 | Val AUC 0.8226 | Val AP 0.8046
# Epoch 014 | Loss 0.4904 | Val AUC 0.8250 | Val AP 0.8082
# Epoch 015 | Loss 0.4857 | Val AUC 0.8281 | Val AP 0.8124
# ...
